# %% [markdown]
# # ICP01 Jupyter Install
# ## Sai Siddartha Reddy Avuthu

# %% [markdown]
# ![Sai_Siddartha_Photograph.jpg](attachment:3dc9862f-61c6-4e29-9164-87ac3421b86a.jpg)
# Hello Professor,
# I am Sai Siddartha Reddy Avuthu, currently pursuing 2nd semester of MS-Bais course. I have 2.5years of experience as Oracle Apex Developer.

# %%
print(" hello world ")
# Out:
#  hello world
